# %% [markdown]
# # GPT
# ## GPT1
# ![image.png](attachment:3c0ce8b5-38d0-48ef-a902-8fd955180c25.png)
#
# ![image.png](attachment:b429c5e1-b6d2-4384-bddf-165af7409566.png)
# 输入文本根据文字输出下一个字
#
# ![image.png](attachment:bb7ce46c-1775-4bff-9fb8-13008c0b51c4.png)
# decoder only （没有了cross attention）
#
# textprediction是预测下一个字，classifier是分类器，是微调下游任务的，预训练的时候不使用
#
# 位置编码是自己学的，用了GELU
#
# ![image.png](attachment:18f3f724-bd20-442e-b935-bae2b7b34fdb.png)
#
# 用了tie weight 注意We是相同的
#
# 微调
#
# ![image.png](attachment:18001cd1-1c58-42a3-99f4-a1d5fb6dabd9.png)
#
# 增加特殊的token transformer指的是预训练的GPT1，最后的选择题linear的结果softmax得到每个选项的概率
#
# 微调的同时进行自回归训练，prediction和classifier的loss不同的权重进一步训练
#
# ![image.png](attachment:d1238c52-393d-4a04-bc49-199148f63ad2.png)

# %% [markdown]
# ## GPT2
#
# ![image.png](attachment:5f3810c9-3ae7-46e5-93db-9a2183b233a8.png)
#
# 希望有一个全能的GPT 不需要微调
#
# ![image.png](attachment:9b81412f-1f0f-4064-ae5d-5e9ee1a9964a.png)
#
# 不再加特殊token，而是加入prompt
#
# ![image.png](attachment:644098d0-e1a2-4354-9b17-8844537fb5bc.png)
# 更加稳定pre-norm
#
# ![image.png](attachment:e7a493d0-3d0c-44b9-bd07-677bf5941c1c.png)

# %% [markdown]
# ## GPT3
# ![image.png](attachment:024066bc-9ba1-4faa-9d98-dd2d6a773f98.png)
#
# ![image.png](attachment:58bf2fa2-6a24-4b73-b175-71a53ca8faea.png)
#
# ![image.png](attachment:95f2510a-b46d-4488-aa92-3e3474588136.png)
#
# 稀疏注意力 只和部分的注意力进行计算
#
# ![image.png](attachment:67879ea4-22f8-456e-925a-30df089ab2e9.png)
#
# seqlen到了2048
# ![image.png](attachment:7d52c724-f05b-4bcc-8fb2-a0657dbabeac.png)

# %% [markdown]
# ## GPT4
#
# ![image.png](attachment:7c2a04b8-8565-493e-9673-ba2011027796.png)
#
# ![image.png](attachment:f90363b1-b523-4856-b5cf-58bf5fda6588.png)
#
# 用小模型能力推算出大模型的能力

# %% [markdown]
# # llama
#
# ![image.png](attachment:31a6b9ff-343c-4bb0-a35c-3681b33f31b2.png)
#
# llama注重模型的数据量
#
# GPT 两者都重视（数据和模型复杂度）
#
# deepseek则注重优化新的算法
#
#
# ## llama1
#
# ![image.png](attachment:af86f5e8-5744-4b06-8bc6-35b9fd8f3374.png)
# ![image.png](attachment:5f36d5d3-24a8-4e3e-9263-b8c5905b1075.png)
#
# ![image.png](attachment:9437e6c6-31bc-4a0d-9995-ad45d32886de.png)
#
# rmsnorm：对数据平移不会改变数据的分布，所以去除
#
# ![image.png](attachment:ca7b795c-8fd9-406b-9886-05c9f5918244.png)
# x×sigmoid == silu  提升精度 但是计算代价较高
#
# ## llama2
#
# ![image.png](attachment:2cac3e14-ffac-4e72-82c2-3138a139ed59.png)
# 更大的数据量
# ![image.png](attachment:c52877ad-5895-45f2-8178-b63288438612.png)
#
# ![image.png](attachment:132728eb-343a-41f0-b9ff-5673b5f3494c.png)
#
# 减少参数量 显存占用 加速
# ![image.png](attachment:1fe13935-6d27-4565-b288-7e66aa2fd151.png)
# 各自复制一份 这样优一一对应了
#
# ![image.png](attachment:d1332ee7-657e-4f18-8656-6545884d3d26.png)

# %% [markdown]
# ## llama3
# ![image.png](attachment:06a61eb6-d4e3-499a-92e7-c5543918479d.png)
#
# ![image.png](attachment:085213e9-b6e0-4135-a2a9-28f8fc08a796.png)
#
# ![image.png](attachment:8f8e1083-beea-4e5f-884d-6c24b2e42beb.png)
#
# ![image.png](attachment:c0b00f43-2d43-4ad7-9418-18a3a2c6ea57.png)
#
# seqlen变成了8096
#
# llama2是用生成的蓄念数据来帮助文本质量分数器 而不是训练llama3
#
# ![image.png](attachment:71eb0530-8efb-4726-a6a1-6c12f9899a73.png)
#
# ![image.png](attachment:2d408b74-561c-4084-a5b8-4e417f98f610.png)
