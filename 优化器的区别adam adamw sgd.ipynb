# %% [markdown]
# # 指数加权
#
# ![image.png](attachment:28d90b63-fcd9-4ff7-b324-98569ad57e4a.png)
#
# β×上次的平均值+（1-β）这次的真实值
#
# 前期都太小了，因为假设了V0等于0，所以可以用/(1-β^t)来做修正

# %% [markdown]
# # SGD
# ![image.png](attachment:0553b116-9bb9-442d-b3f3-bf22bd8b9c39.png)

# %% [markdown]
# # 动量
# ![image.png](attachment:6a555657-7e41-406a-8ffc-d84e058cd093.png)
# ![image.png](attachment:a9aa7556-974d-461c-aceb-a1e962e947f9.png)
# SGD某个值梯度大会产生震荡（前图），动量通过指数平滑进行平均，减小了震荡（后图）

# %% [markdown]
# # RMSProp
# ![image.png](attachment:b4c149c6-6c16-4673-879e-c298c1d6e058.png)
# momentum是一阶的  那么RMSProp就是二阶的对齐， 减少震荡

# %% [markdown]
# # adam
# ![image.png](attachment:1cf3beb0-732a-44ec-bcd4-a17934a87089.png)
#
# 就是momentum+RMSProp+修正
#
# # adamW
# ![image.png](attachment:bf2e16ad-b6cf-450b-85d6-08404702f7f9.png)
#
# adam做了weight decay  防止参数过大 提高泛化性，这与L2正则是不同的
#
# ![image.png](attachment:6a7aec90-6b03-46e6-9238-b86869864add.png)
# SGD L2正则和weight decay是一样的
#
# ![image.png](attachment:2e26481c-bd1e-4e5c-b4ce-08768c39c48b.png)
# 但是adam运算太多  最后算出来的不会是权重衰减
#
# ![image.png](attachment:2757a940-d348-424a-828c-b08b5fc5566c.png)
