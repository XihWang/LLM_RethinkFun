# %% [markdown]
# ![image.png](attachment:fd90a89a-07fb-4017-8848-01f67e79b9b0.png)
#
# cpu告诉完成任务  gpu是高吞吐高并行
#
# ![image.png](attachment:aa4e18af-6375-49a4-83d6-a4bb12dbc501.png)
#
# ![image.png](attachment:feaa6b61-f96d-4a7c-8b28-a15e460a1268.png)
#
# ![image.png](attachment:22b78b34-350b-4f64-8588-3a3fadd344e4.png)
# 每个SM有16个int32 CUDA core，16个FLOAT32 CUDA core，8个FLOAT64 CUDA core
#
# ![image.png](attachment:de1ce55b-2d9a-4e70-a0a9-bfaa0f68d06d.png)
# 至少需要100次的浮点运算才能满负荷

# %% [markdown]
# ![image.png](attachment:6af623d8-275d-4ec6-92ed-045a1bbcfbcb.png)
# 计算量是数据量的N倍
#
# ![image.png](attachment:9639266b-1d64-4152-9430-5545da5ef8d1.png)
#
# ![image.png](attachment:70a4d7d1-0201-424b-b695-686d35f57318.png)
# NVLink是不同的显卡之间的多卡通信
#
# PCIE负责和主机通信
#
# HBM是在芯片外部的，也就是所谓的显存
#
# L1 L2都在芯片的内部
#
# A100有108个SM，里面有L0 L1 cache，外面有L2cache

# %% [markdown]
# ![image.png](attachment:eaea0303-8dff-47ec-beee-b26d66772762.png)
# ![image.png](attachment:216e7fa9-526b-45d2-8096-e7d760b459e9.png)
# 一个tensor core能在一个时钟周期内完成一个矩阵乘法和一个加法
#
# ![image.png](attachment:7c19d751-b11c-4e71-8eee-d3507cc3227b.png)
# ![image.png](attachment:29966cc9-7a7e-4c31-b652-46566c25b669.png)
# 稀疏性计算的算力是2倍
