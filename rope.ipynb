# %% [markdown]
# ![image.png](attachment:24952022-4365-426a-bf2c-cc71444dada3.png)
# ![image.png](attachment:c8243d20-8c4d-425f-a0f6-7c604df292f2.png)
# ![image.png](attachment:bb551312-a9e0-4abf-8672-0b16ad8df70c.png)
#
# 乘以旋转矩阵  逆时针旋转theta角度

# %% [markdown]
# 旋转角度的性质
#
# ![image.png](attachment:1c86883e-7396-431e-80ff-fcd60b271fa3.png)
#
# ![image.png](attachment:d97957f1-82d1-4714-9cdb-8e9b34c6c5ae.png)
#
# 所以旋转以后的Q和K求点积考虑了相对位置关系m-n
#
# ![image.png](attachment:26c35f76-3fa0-48a0-b5bd-132fe642e705.png)
#
# m是token的位置  f是频率 第一个二维子空间频率最大

# %% [markdown]
# ![image.png](attachment:f8a21c10-2131-4b3b-80ae-0c622904a3cd.png)
#
# ![image.png](attachment:615b5da0-9e88-4da1-b619-56bb88f23d7d.png)
#
# 哈达玛积就是对应位置的相乘，一个token一个旋转矩阵（dxd），每两个hidden_size为一组，进行旋转。前面的hidden_size的频率大，周期短，转得快变化大。（就像秒针）   后面的频率小，周期大，转得慢像时针
#
# 前面的token的m小，所以变化的也慢

# %% [markdown]
# ![image.png](attachment:02efb0ad-996c-4912-9e4d-fca90c80cf00.png)
# ![image.png](attachment:bd88b63e-c02b-417d-b3d8-2613dbf5ee31.png)
#
# 不一定要相邻的两个hidden_size进行处理，任何的两个hidden_size都可以作为一个坐标。  所以sin的正负我们可以前面全取正数，后面全负数（相当于第一个hidden和第d/2个进行组合）
