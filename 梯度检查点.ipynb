# %% [markdown]
# ![image.png](attachment:ca584711-f379-49c7-a8b8-6de2caeb443c.png)
#
# 减少了激活值的保存，降低了内存的需求。但是计算速度会降低（因为中间没有保存的激活值会重新计算）。哪些激活值计算代价大但是显存占用少的优先保存的。
#
#
# ![image.png](attachment:90612ef5-1e76-404b-91d9-41e9b2f5d5ca.png)
#
# 计算速度交换显存，如果batchsize=1还是显存不够可以用这个方法
